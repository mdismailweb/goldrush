# %%
import pandas as pd
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split, cross_val_score, RepeatedKFold
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
df = pd.read_csv("gold_price_forecasting_dataset.csv")

df
# Out:
#             date    adj close        close         high          low  \
# 0     2021-06-11  1877.400024  1877.400024  1902.300049  1875.199951
# 1     2021-06-14  1864.000000  1864.000000  1866.599976  1846.500000
# 2     2021-06-15  1854.500000  1854.500000  1867.199951  1854.400024
# 3     2021-06-16  1859.500000  1859.500000  1860.099976  1809.199951
# 4     2021-06-17  1773.800049  1773.800049  1823.300049  1769.599976
# ...          ...          ...          ...          ...          ...
# 1162  2026-01-26  5079.700195  5079.700195  5095.600098  5052.200195
# 1163  2026-01-27  5079.899902  5079.899902  5079.899902  5079.899902
# 1164  2026-01-28  5301.600098  5301.600098  5301.600098  5301.600098
# 1165  2026-01-29  5318.399902  5318.399902  5586.200195  5097.500000
# 1166  2026-01-30  4713.899902  4713.899902  5440.500000  4700.000000
#
#              open  volume         ma_7        ma_30        ma_90  \
# 0     1900.900024     349  1887.828561  1860.180005  1790.618891
# ...

# %%
x = df.drop(columns =["date", "adj close", "high"])
y = df["high"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = XGBRegressor(n_estimators=100,        # Number of trees
    max_depth=6,             # Maximum tree depth
    learning_rate=0.1,       # Step size shrinkage
    subsample=0.8,           # Fraction of samples per tree
    colsample_bytree=0.8,    # Fraction of features per tree
    random_state=42)

# %%
model.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([2170.5732, 4136.9487, 1818.2961, 1769.3269, 3338.8562, 1653.6053,
#        2069.7478, 1852.5134, 1783.9603, 1660.4398, 1836.6704, 1959.2693,
#        2627.6416, 1825.9199, 2006.2573, 2923.9446, 1656.2759, 1795.7014,
#        2039.748 , 1670.1617, 3834.6785, 1809.0674, 2001.822 , 1839.5479,
#        1934.305 , 1667.7622, 4204.4336, 2731.773 , 1854.723 , 1954.4558,
#        2654.3523, 1856.4786, 3271.0522, 2494.6526, 2753.0242, 2922.1143,
#        1845.0115, 2332.0078, 1869.4648, 3036.1714, 2655.879 , 1790.7888,
#        1930.4777, 1940.2834, 1856.3221, 1818.0636, 3036.077 , 1786.7179,
#        1982.1952, 4217.1426, 1793.3073, 2319.4443, 1786.5759, 2513.8906,
#        1922.1136, 2341.1614, 1926.9233, 3324.5974, 1969.314 , 3340.5037,
#        1685.5878, 1829.7938, 1725.1295, 1899.967 , 2384.8892, 1955.3143,
#        2610.9724, 1922.0564, 1836.6759, 1943.6564, 4325.277 , 1654.395 ,
#        4596.6475, 1809.7548, 1970.0789, 3412.7974, 1852.978 , 1855.1416,
# ...

# %%
mean_absolute_error(y_pred, y_test)
# Out:
# 12.057092389489851

# %%
# # The user should enter:

#  Open price
open_p = float(input("Enter the Open Price in Dollars: "))
# High price (today)
high_today = float(input("Enter the High Price in Dollars: "))
# Low price
low_p = float(input("Enter the Low Price in Dollars: "))
# Volume
vol = float(input("Enter the Volume of Gold Sold: "))


prediction = model.predict([[open_p, low_p, vol]])

print(f"Tomorrow's predicted highest price is: ${prediction}")

# Your app will automatically calculate:
# Moving averages
# RSI
# MACD
# Volatility
# Bollinger Bands
# Daily return

# The model will then predict:
# Tomorrow’s highest price
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 13
#       9 # Volume
#      10 vol = int(input("Enter the Volume of Gold Sold: "))
# ---> 13 prediction = model.predict([[open_p, low_p, vol]])
#      15 print(f"Tomorrow's predicted highest price is: ${prediction}")
#      17 # Your app will automatically calculate:
#      18 # Moving averages
#      19 # RSI
#    (...)     25 # The model will then predict:
#      26 # Tomorrow’s highest price
#
# File ~/Python/Machine Learning/Gold Price Pred app/.venv/lib/python3.13/site-packages/xgboost/core.py:774, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     772 for k, arg in zip(sig.parameters, args):
#     773     kwargs[k] = arg
# --> 774 return func(**kwargs)
#
# ...
